# %% [markdown]
# <a href="https://colab.research.google.com/github/yanghyensik3955/Homework/blob/main/untitled10%2026~33%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#26
intdata1=20
octdata=0o24
hexdata=0x14
fdata1=1.0
fdata2=2.

intdata1=5
intdata2=10
ret=intdata2/intdata1
print(type(ret))
#<class'float'>

numdata=2e2   #200
print(type(numdata))
#<class 'float'>

#27
cData1=1+1J
cData2=complex(1,1)
print(cData1==cData2)
#True

print(cData1.real)
print(cData2.imag)
#1.0, 1.0

complexData1=1_5J
complexdata2=complex(2,3)
print(complexData1.conjugate())
print(complexData2.conjugate())
#(1+5j), (2-3j)

#28
intdata= -8
floatData=3.14
complexData=3+4j
print(abs(intdata))
print(abs(floatdata))
print(abs(complexData))
#8, 3.14, 5.0

#29
x=11113
y=23
ret1=x//y
ret2=x%y
print(f'{x}을(를){y}(으)로 나누면 몫이{ret1},나머지가 {ret2}입니다)
#11113을(를)23으(로)나누면 몫이 483,나머지가 4입니다

x=11113
y=23
ret1, ret2,=divmods(x,y)
print(f'{x}을(를){y}(으)로 나누면 몫이{ret1},나머지가 {ret2}입니다)
#11113을(를)23으(로)나누면 몫이 483,나머지가 4입니다


#30
ret=round(42.195)
print(ret)
#42

ret=round(42.195, 0)
print(ret)
#42.0

ret=round(42.195, 1)
print(ret)
#42.2

ret=round(42.195,-1)
print(ret)
#40.0

#31
floatData=1234.5
intData=int(floatData)
print(f'intdata{intdata}자료형은{type(input)}입니다.')
#intdata1234자료형은 <class 'int'>입니다

strdata='1234'
intdata=int(strdata)
print(f'intdata{intdata}자료형은{type(input)}입니다.')
#intdata1234자료형은 <class 'int'>입니다

strdata='1234.5'
intdata=int(strdata)
print(f'float{floatdata}자료형은 {type(floatdata)}입니다')

print(float('2e5'))
print(float('2e-3'))
#200000.0, 0.002



1  intData = 1234; strData1 = str(intData)
2  floatData1 = 1234.5; strData2 = str(floatData1)
3  floatData2 = 1e-3; strData3 = str(floatData2)
4  print(f'정수 {intData} => 문자열 {strData1}, {type(strData1)}')
5  print(f'실수 {floatData1} => 문자열 {strData2}, {type(strData2)}')
6  print(f'실수 {floatData2} => 문자열 {strData3}, {type(strData3)}')

정수 1234 => 문자열 1234, <class 'str'>
실수 1234.5 => 문자열 1234.5, <class 'str'>
실수 0.001 => 문자열 0.001, <class 'str'>


h1=hex(97)
h2=hex(98)
print(h1)
print(h2)
#0x61, 0x62

print(h1+h2)
0x610x62

1  hexStr1 = '0x11'
2  hexStr2 = '0x2a'
3  int1 = int(hexStr1, base=16)
4  int2 = int(hexStr2, base=16)
5  hexAnswer = hex(int1 + int2)
6  print(f'{hexStr1} + {hexStr2} = {hexAnswer}')

0x11 + 0x2a = 0x3b

b1=bin(97)
b2=bin(98)
print(b1)
print(b2)
#0b1100001, 0b1100010

print(b1+b2)
#0b11000010b1100010

1  binStr1 = '0b1011'
2  binStr2 = '0b1001'
3  int1 = int(binStr1, base=2)
4  int2 = int(binStr2, base=2)
5  binAnswer = bin(int1 + int2)
6  print(f'{binStr1} + {binStr2} = {binAnswer}')

0b1011 + 0b1001 = 0b10100
# Out:
#   File "/tmp/ipython-input-4013347125.py", line 48
#     print(f'{x}을(를){y}(으)로 나누면 몫이{ret1},나머지가 {ret2}입니다)
#           ^
# SyntaxError: unterminated f-string literal (detected at line 48)
