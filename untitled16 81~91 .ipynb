# %% [markdown]
# <a href="https://colab.research.google.com/github/yanghyensik3955/Homework/blob/main/untitled16%2081~91%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#81
profile=['홍길동','남자','18세','도적','초능력자']
logData=';'join(profile)
print(logData)

profile=['홍길동','남자','18세','도적','초능력자']
logData=';'join(profile)

#82
logData='홍길동;남자;18세;도적;초능력자'
profile=logData.split(';')
print(profile)

text='나느 파이썬을 사랑합니다'
print(text.split())

profile='이름:홍길동 나이:18세 성뱔:남자 국적:조선 직업:도적 특기:초능력'
for Data in profile.split():
  key, val = data.split(';')
  print(f'{key}-->{val}')

#83
text='이 문장의 양쪽에는 공백이 있습니다 '
print(f'<{text.strip()}>')
print(f'<{text.Istrip()}>')
print(f'<{text.rstrip()}>')

url='www.python.com'
print(url.strip('cmow.'))

print(url.lstrip('cmow.'))
print(url.rstrip('cmow.'))

#84
text='문자열:파이썬에서 시퀸스 자료 중 하나임'
ret=text.replce('문자열','텍스트')
print(ret)

text='매일 많은 일이 일어납니다'
ret=text.replace('일','사건')
print(ret)

#85
numData=['5','27','342','1004']
for numstr in numData:
  ret=numstr.zfill(4)
  print(ret)

numData=['-5','-27','-342','-1004']
for numstr in numData:
  ret=numstr.zfill(4)
  print(ret)

#86
names=['유비','관우','장비','조운','제갈량']
for idx,name in enumerate(names,start=1):
  order=format(idx,'03')
  print(f'{order}-{name}')

#87
lyrics='A lot of Things occur Each Day!'
print(lyrics.upper())
print(lyrics.lower())
print(lyrics)

#88
randstr='nk315nnkakkavnzrit'
ret=sorted(randstr)
print(ret)

final=".join(ret)
print(final)

#89
expression='123 + 456'
answer=eval(expression)
print(f'{expression}={answer}')

expression='round(3.14)'
print(f'{expression}={eval(expression)}')

ret=eval('안녕하세요')

#90
strData='[info]seoul if the capital of korea'
cityinfo=strData.removeprefix('[info]')
print(cityinfo)

strData='이것으로 문장을 마무리합니다.<EOD>'
ret=strData.removesuffix('<EOD>')
print(ret)

#91
strData='python'
byteData=strData.encode()
print(byteData)

for idx,c in enumerate(strData):
  print(f'strData[{idx}]={c}')

for idx c in enumerate(byteData):
  print(f'byteData[{idx}]={c},{hex(c)}')

strData='파이썬'
byteData=strData.encode()
print(byteData)

strData='파이썬'
byteData=strData.encode('CP949')
print(byteData)
